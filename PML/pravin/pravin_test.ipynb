# %%
print("hello world")
# Out:
# hello world

# %%
print("hello")
# Out:
# hello

# %%
1+1
# Out:
# 2

# %%
3+3
# Out:
# 6

# %%
2**4
# Out:
# 16

# %%
x= 1+2

# %%
print(x)
# Out:
# 3

# %%
y=2

# %%
print(x+y)
# Out:
# 5

# %%
x
# Out:
# 3

# %%
y
# Out:
# 2

# %%
z=x ** y

# %%
z
# Out:
# 9

# %%
z
# Out:
# 9

# %%
z
# Out:
# 31

# %%
t = np.linspace(-5*np.pu, 5*np.pi, 50)
plt.plot(t, np.sin(t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 t = np.linspace(-5*np.pu, 5*np.pi, 50)
#       2 plt.plot(t, np.sin(t))
#
# NameError: name 'np' is not defined
