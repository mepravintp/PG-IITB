# %%
lst = [5, 10, 20, 30, 40, 50,60]

print(lst[0])
print(lst[-1])
print(lst[1:4])
print(lst[1:-1])
# Out:
# 5
# 60
# [10, 20, 30]
# [10, 20, 30, 40, 50]

# %%
lst = ['a', 'b', 'c', 'd', 'e']

lst[2]='z'


lst[::-1]

lst[0::2]
# Out:
# ['a', 'z', 'e']

# %%
lst = [10, 20, 30, 40, 50,60]



if len(lst) % 2 != 0:
    print(lst[len(lst)//2])
else:
    print(lst[len(lst)//2], lst[len(lst)//2 +1])
# Out:
# 40 50

# %%
x=5
result = "Even" if x % 2 == 0 else "Odd"

# %%
lst = [1, 2, 3, 4, 5, 6]

[x for x in lst if x%2==0]
# Out:
# [2, 4, 6]

# %%
[x *x for x in range(1,6)]
# Out:
# [1, 4, 9, 16, 25]

# %%
lst = [1, 2, 3, 4, 5]

[(x*x*x) for x in lst if x%2!=0]
# Out:
# [1, 27, 125]
