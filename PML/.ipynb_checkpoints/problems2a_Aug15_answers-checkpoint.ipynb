# %% [markdown]
# 1) Count Even Numbers in List: Write a function that takes a list of integers and returns how many of them are even.
#
#     Input: [1, 2, 4, 5, 6]
#     Output: 3

# %%
def countEven(l):
    cnt=0
    for i in l:
        if i%2==0:
            cnt+=1
    return cnt
print(countEven(range(0,10)))
# Out:
# 5

# %% [markdown]
# 2) Count Even and Odd Numbers in List: Write a function that takes a list of integers and returns how many of them are even and how many are odd.
#
# Input: [1, 2, 4, 5, 6]
# Output: 3, 2

# %%
def countAll(l):
    even=0
    odd=0
    for i in l:
        if i%2==0:
            even+=1
        else:
            odd+=1
    return even, odd

print(countAll(range(0,3)))
# Out:
# (2, 1)

# %% [markdown]
# 3) Check Palindrome Number: Write a function that takes an integer and returns True if it is a palindrome, otherwise False.
#
#     Input: 121
#     Output: True
#
#     Input: 123
#     Output: False

# %%
 def checkPallindrome(n):
     orig=n
     rev=0
     while n > 0:
         mod =n % 10
         rev= rev * 10 + mod
         n=n//10
     return orig==rev

print(checkPallindrome(123))

def checkPallinStr(n):
    s=str(n)
    return n==s[::-1]
print(checkPallindrome(121))
# Out:
# False
# True

# %% [markdown]
# 4) Fahrenheit to Celsius Conversion
#
#     Write a function `fahrenheit_to_celsius(f)` that converts Fahrenheit to Celsius.
#
#     Then write another function `temp_hot(f)` that takes the temperature value in Fahrenheit, calls `fahrenheit_to_celsius`, and returns True if temperature in Celsius is greather than 50, otherwise False.
#
#     Example:
#     Input: fahrenheit_to_celsius(212)
#     Output: 100
#
#     Input: temp_hot(212)
#     Output: True
#
#     Input: temp_hot(32)
#     Output: False

# %%
def fahrenheit_to_celsius(f):
    return (f - 32) * 5 / 9

def temp_hot(f):
    return fahrenheit_to_celsius(f) > 50

print(temp_hot(32))
print(temp_hot(212))
print( fahrenheit_to_celsius(212))
# Out:
# False
# True
# 100.0

# %% [markdown]
# 5) Write a function that takes a list of integers and returns the difference between squares of the largest and smallest number.
#
#     Input: [1, 2, 3, 4]
#     Output: 15
#
#     Input: [2, 6, 3]
#     Output: 32

# %%
def diff(l):
    max=l[0]
    min=l[0]
    for i in l:
        if i >max:
            max=i
        elif i < min:
            min=i
    #print(max,min)
    return (max **2) - (min **2)

print(diff([1, 2, 3, 4]))
# Out:
# 15

# %% [markdown]
# 6) Write a function that returns the product of all numbers in the list.
#
#     Input: [2, 3, 4]
#     Output: 24

# %%
def sumOfN(l):
    if len(l) == 0:
        return 0
    prod=1
    for i in l:
        prod=prod*i

    return prod

L=[2, 3, 4,5]

sumOfN(range(1,5))
# Out:
# 24
