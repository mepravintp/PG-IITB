# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\pravi\\PG IITB\\cricket_object_detection\\outputs\\annotations_cells.csv')
print(df.head())
# Out:
#                  image_name  cell_row  cell_column  label
# 0  -NeNQ3KDNlitNqsWDKM8.jpg         1            1      0
# 1  -NeNQ3KDNlitNqsWDKM8.jpg         1            2      0
# 2  -NeNQ3KDNlitNqsWDKM8.jpg         1            3      3
# 3  -NeNQ3KDNlitNqsWDKM8.jpg         1            4      3
# 4  -NeNQ3KDNlitNqsWDKM8.jpg         1            5      3

# %%
#Plot a bar graph of number of annotations per class
import matplotlib.pyplot as plt 


df=pd.read_csv('C:\\Users\\pravi\\PG IITB\\cricket_object_detection\\outputs\\annotations_cells.csv')
print(df.head())

#distinct images
distinct_images=df['image_name'].nunique()
print(f"Distinct images: {distinct_images}")
# Out:
#                  image_name  cell_row  cell_column  label
# 0  -NeNQ3KDNlitNqsWDKM8.jpg         1            1      0
# 1  -NeNQ3KDNlitNqsWDKM8.jpg         1            2      0
# 2  -NeNQ3KDNlitNqsWDKM8.jpg         1            3      3
# 3  -NeNQ3KDNlitNqsWDKM8.jpg         1            4      3
# 4  -NeNQ3KDNlitNqsWDKM8.jpg         1            5      3
# Distinct images: 50
