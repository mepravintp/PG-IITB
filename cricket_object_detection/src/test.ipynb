# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\\Users\\pravi\\PG IITB\\cricket_object_detection\\outputs\\annotations_cells_modified.csv", encoding='latin1')

df.head()
# Out:
#                  image_name  cell_row  cell_column  label
# 0  -NeNQ3KDNlitNqsWDKM8.jpg         1            1      0
# 1  -NeNQ3KDNlitNqsWDKM8.jpg         1            2      0
# 2  -NeNQ3KDNlitNqsWDKM8.jpg         1            3      3
# 3  -NeNQ3KDNlitNqsWDKM8.jpg         1            4      3
# 4  -NeNQ3KDNlitNqsWDKM8.jpg         1            5      3

# %%
df["image_name"].unique()

#count all images
len(df["image_name"].unique())


#get me images w
# Out:
# 202

# %%
df["image_name"].unique()

#image count


#df.groupby("image_name").count()

#group by label column to see distribution of labels
#df.groupby("label").count()

#plot distribution of labels
import matplotlib.pyplot as plt
label_counts = df['label'].value_counts()
print(label_counts)
label_counts.plot(kind='bar')
plt.xlabel('Label')
plt.ylabel('Count') 
plt.title('Distribution of Labels in Annotations')
plt.show();

#percentage distribution of labels
label_percentage = df['label'].value_counts(normalize=True) * 100
print(label_percentage)
# Out:
# label
# 0    8360
# 1    2117
# 3    1353
# 2    1098
# Name: count, dtype: int64
# label
# 0    64.665842
# 1    16.375309
# 3    10.465656
# 2     8.493193
# Name: proportion, dtype: float64
