# %% [markdown]
# # Visualize Model Predictions on Images
# This notebook reads the final predictions CSV, overlays color-coded cell grids on each image, and saves the processed images for inspection.

# %%
# Section 1: Import Required Libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
# Section 2: Read Predictions CSV
csv_path = r"C:\Users\pravi\PG IITB\cricket_object_detection\outputs\final_predictions_pravin.csv"
pred_df = pd.read_csv(csv_path)
print("Length of pred_df:", len(pred_df))
cell_cols = [f"c{str(i+1).zfill(2)}" for i in range(64)]

print("Number of unique images:", len(pred_df["ImageFileName"].unique()))
# Out:
# Length of pred_df: 82
# Number of unique images: 41

# %%
# Section 3: Load Images and Process Grid Labels
image_dir = r"C:\Users\pravi\PG IITB\cricket_object_detection\data\train_modified"
output_dir = r"C:\Users\pravi\PG IITB\cricket_object_detection\outputs\processed_pravin"
os.makedirs(output_dir, exist_ok=True)
cell_height, cell_width = 75, 100  # For 800x600 images, 8x8 grid

# %%
# Section 4: Visualize and Color-Code Cell Grids
color_map = {0: 'gray', 1: 'red', 2: 'green', 3: 'blue'}

from matplotlib.patches import Rectangle

def visualize_and_save(img_name, cell_labels):
    img_path = os.path.join(image_dir, img_name)
    if not os.path.exists(img_path):
        print(f"Image not found: {img_name}")
        return
    img = io.imread(img_path)
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.imshow(img)
    for idx, label in enumerate(cell_labels):
        r, c = divmod(idx, 8)
        y1, y2 = r * cell_height, (r + 1) * cell_height
        x1, x2 = c * cell_width, (c + 1) * cell_width
        # Draw cell border
        rect = Rectangle((x1, y1), cell_width, cell_height, fill=False, edgecolor=color_map[label], linewidth=2)
        ax.add_patch(rect)
        # Draw darker background highlight for labels 1,2,3
        if label in [1, 2, 3]:
            highlight = Rectangle((x1, y1), cell_width, cell_height, fill=True, facecolor=color_map[label], alpha=0.5, edgecolor=None)
            ax.add_patch(highlight)
    ax.set_title(img_name)
    ax.axis('off')
    plt.tight_layout()
    # Save image
    out_path = os.path.join(output_dir, img_name)
    fig.savefig(out_path)
    plt.close(fig)

# %%
# Section 5: Save Processed Images
for idx, row in pred_df.iterrows():
    img_name = row['ImageFileName']
    print(f"Processing image: {img_name} , {idx+1}/{len(pred_df)}")
    cell_labels = [row[col] for col in cell_cols]
    visualize_and_save(img_name, cell_labels)
print(f"Processed images saved to {output_dir}")
# Out:
# Processing image: henry-nicholls-in-action-against-bangladesh-appti-100309511-16x9_0.jpg , 1/82
# Processing image: hq720 (2).jpg , 2/82
# Processing image: hq720 (4).jpg , 3/82
# Processing image: hq720.jpg , 4/82
# Processing image: illustration-of-one-cricket-bat-with-wickets-and-a-blank-gold-banner-M1PT4P.jpg , 5/82
# Processing image: india-batter-kl-rahul-in-action-during-the-anderson-tendulkar-trophy-2025-1758805449571-16_9.jpg , 6/82
# Processing image: india-insecure-batters.jpg , 7/82
# Processing image: india-keeper-batter-rishabh-pant-in-action-during-lord-s-test-against-england-1752860568288-16_9.jpg , 8/82
# Processing image: india-keeper-batter-rishabh-pant-in-action-on-day-03-at-lord-s-test-1752331897754-16_9.jpg , 9/82
# Processing image: Innovative-Cricket-Shots-Invented-by-Players-1 (1).jpg , 10/82
# Processing image: inside-out (1).jpg , 11/82
# Processing image: joe-root-in-action-against-india-in-hyderabad-reuters-253545582-16x9_0.jpg , 12/82
# Processing image: jos-buttler-scoop-shot (1).jpg , 13/82
# Processing image: kss-kashmiri-willow-single-blade-cricket-bat-product-images-orvhvzncxvt-p601852135-0-202305262152.jpg , 14/82
# Processing image: large.jpg , 15/82
# Processing image: maxresdefault (2).jpg , 16/82
# Processing image: maxresdefault.jpg , 17/82
# Processing image: nairobi-kenya-august-28-kenya-batter-pushkar-sharma-in-action-during-a-training-section-in-preparation-for-international-cricket-council-icc-2XY7WN4.jpg , 18/82
# Processing image: nic-maddinson-cancer.jpg , 19/82
# Processing image: phil-salt-2025-07-076840d68aefcdf2d95686e1cb51d8b1-1200x675.jpg , 20/82
# Processing image: red-cricket-ball-and-bat-on-grass-close-up-EFW04F.jpg , 21/82
# Processing image: rn-image_picker_lib_temp_339c17e7-ff07-420b-aed2-7f8944afb37e.jpg , 22/82
# Processing image: rn-image_picker_lib_temp_85b0cf69-581f-4ac7-9d33-80c1d183976e.jpg , 23/82
# Processing image: rohit-sharma-getty-1577360042 (1).jpg , 24/82
# Processing image: rudraym-rm-single-blade-light-weight-hard-tennis-circle-scoop-kashmir-willow-cricket-bat-orange-119565.jpg , 25/82
# Processing image: rudraym_rm_ak47_bandook_double_blade_light_weight_hard_tennis_scoop_single_blade_cane_singapore_handle_wood_kashmir_willow_cricket_bat_leather_soft_tennis_wood_bat_green.jpg , 26/82
# Processing image: Safsof_rubber-foam-toys_CKS-29_01.jpg , 27/82
# Processing image: sarfaraz-khan-1600_20251024145836.jpg , 28/82
# Processing image: Single-Blade-Cricket-Bat-2.jpg , 29/82
# Processing image: single-teal-cricket-bat-textured-grip-white-background-399971957.jpg , 30/82
# Processing image: SOFT-TENNIS-scaled.jpg , 31/82
# Processing image: SportsWing_SingleBlade-WithoutScoop-SoftPremiumTennisBat_Black_1.jpg , 32/82
# Processing image: Surya-kumar-yadavplaying-scoop-shot-canva.jpg , 33/82
# Processing image: types-of-cricket-shots (1).jpg , 34/82
# Processing image: ultimate-long-handle-cricket-bat-802361334-9bc31jbl.jpg , 35/82
# Processing image: vintage_finisher_one_1.jpg , 36/82
# Processing image: WhatsApp_Image_2023-09-08_at_04.17.17 (1).jpg , 37/82
# Processing image: WhatsApp_Image_2023-09-08_at_04.23.15 (1).jpg , 38/82
# Processing image: WhatsApp_Image_2023-09-08_at_04.41.27_3 (1).jpg , 39/82
# Processing image: WhatsApp_Image_2024-04-23_at_16.58.52_2.jpg , 40/82
# Processing image: zndz9afh3drxw54k_1642605650 (1).jpg , 41/82
# Processing image: henry-nicholls-in-action-against-bangladesh-appti-100309511-16x9_0.jpg , 42/82
# Processing image: hq720 (2).jpg , 43/82
# Processing image: hq720 (4).jpg , 44/82
# Processing image: hq720.jpg , 45/82
# Processing image: illustration-of-one-cricket-bat-with-wickets-and-a-blank-gold-banner-M1PT4P.jpg , 46/82
# Processing image: india-batter-kl-rahul-in-action-during-the-anderson-tendulkar-trophy-2025-1758805449571-16_9.jpg , 47/82
# Processing image: india-insecure-batters.jpg , 48/82
# Processing image: india-keeper-batter-rishabh-pant-in-action-during-lord-s-test-against-england-1752860568288-16_9.jpg , 49/82
# Processing image: india-keeper-batter-rishabh-pant-in-action-on-day-03-at-lord-s-test-1752331897754-16_9.jpg , 50/82
# Processing image: Innovative-Cricket-Shots-Invented-by-Players-1 (1).jpg , 51/82
# Processing image: inside-out (1).jpg , 52/82
# Processing image: joe-root-in-action-against-india-in-hyderabad-reuters-253545582-16x9_0.jpg , 53/82
# Processing image: jos-buttler-scoop-shot (1).jpg , 54/82
# Processing image: kss-kashmiri-willow-single-blade-cricket-bat-product-images-orvhvzncxvt-p601852135-0-202305262152.jpg , 55/82
# Processing image: large.jpg , 56/82
# Processing image: maxresdefault (2).jpg , 57/82
# Processing image: maxresdefault.jpg , 58/82
# Processing image: nairobi-kenya-august-28-kenya-batter-pushkar-sharma-in-action-during-a-training-section-in-preparation-for-international-cricket-council-icc-2XY7WN4.jpg , 59/82
# Processing image: nic-maddinson-cancer.jpg , 60/82
# Processing image: phil-salt-2025-07-076840d68aefcdf2d95686e1cb51d8b1-1200x675.jpg , 61/82
# Processing image: red-cricket-ball-and-bat-on-grass-close-up-EFW04F.jpg , 62/82
# Processing image: rn-image_picker_lib_temp_339c17e7-ff07-420b-aed2-7f8944afb37e.jpg , 63/82
# Processing image: rn-image_picker_lib_temp_85b0cf69-581f-4ac7-9d33-80c1d183976e.jpg , 64/82
# Processing image: rohit-sharma-getty-1577360042 (1).jpg , 65/82
# Processing image: rudraym-rm-single-blade-light-weight-hard-tennis-circle-scoop-kashmir-willow-cricket-bat-orange-119565.jpg , 66/82
# Processing image: rudraym_rm_ak47_bandook_double_blade_light_weight_hard_tennis_scoop_single_blade_cane_singapore_handle_wood_kashmir_willow_cricket_bat_leather_soft_tennis_wood_bat_green.jpg , 67/82
# Processing image: Safsof_rubber-foam-toys_CKS-29_01.jpg , 68/82
# Processing image: sarfaraz-khan-1600_20251024145836.jpg , 69/82
# Processing image: Single-Blade-Cricket-Bat-2.jpg , 70/82
# Processing image: single-teal-cricket-bat-textured-grip-white-background-399971957.jpg , 71/82
# Processing image: SOFT-TENNIS-scaled.jpg , 72/82
# Processing image: SportsWing_SingleBlade-WithoutScoop-SoftPremiumTennisBat_Black_1.jpg , 73/82
# Processing image: Surya-kumar-yadavplaying-scoop-shot-canva.jpg , 74/82
# Processing image: types-of-cricket-shots (1).jpg , 75/82
# Processing image: ultimate-long-handle-cricket-bat-802361334-9bc31jbl.jpg , 76/82
# Processing image: vintage_finisher_one_1.jpg , 77/82
# Processing image: WhatsApp_Image_2023-09-08_at_04.17.17 (1).jpg , 78/82
# Processing image: WhatsApp_Image_2023-09-08_at_04.23.15 (1).jpg , 79/82
# Processing image: WhatsApp_Image_2023-09-08_at_04.41.27_3 (1).jpg , 80/82
# Processing image: WhatsApp_Image_2024-04-23_at_16.58.52_2.jpg , 81/82
# Processing image: zndz9afh3drxw54k_1642605650 (1).jpg , 82/82
# Processed images saved to C:\Users\pravi\PG IITB\cricket_object_detection\outputs\processed_pravin
