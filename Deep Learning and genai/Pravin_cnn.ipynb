# %% [markdown]
# ## Part A: Convolutional Neural Networks (CIFAR-100)
# ### Environment and Data Preparation

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
import numpy as np

print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow version: 2.19.0

# %% [markdown]
# #### Load and Normalize CIFAR-100 Dataset

# %%
# Load the CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Normalize image data to the range [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 100)
# x_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 100)

# %% [markdown]
# ### A1: Design and Train CNN from Scratch

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax') # 100 classes for CIFAR-100
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        12,900 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 171,812 (671.14 KB)
#  Trainable params: 171,812 (671.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Train the CNN Model

# %%
# Train the model
history_scratch = model.fit(x_train, y_train,
                          epochs=60, # Increased number of epochs
                          batch_size=64,
                          validation_data=(x_test, y_test),
                          verbose=1)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"\nTest Accuracy (Scratch Model): {accuracy:.4f}")
# Out:
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.3820 - loss: 2.3200 - val_accuracy: 0.3760 - val_loss: 2.4679
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 87ms/step - accuracy: 0.3862 - loss: 2.2987 - val_accuracy: 0.3708 - val_loss: 2.4745
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.3875 - loss: 2.2823 - val_accuracy: 0.3760 - val_loss: 2.4543
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.3894 - loss: 2.2670 - val_accuracy: 0.3709 - val_loss: 2.4760
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.3947 - loss: 2.2444 - val_accuracy: 0.3753 - val_loss: 2.4612
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 88ms/step - accuracy: 0.3963 - loss: 2.2366 - val_accuracy: 0.3709 - val_loss: 2.4938
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.3952 - loss: 2.2286 - val_accuracy: 0.3779 - val_loss: 2.4608
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.4015 - loss: 2.2002 - val_accuracy: 0.3761 - val_loss: 2.5024
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.4027 - loss: 2.1945 - val_accuracy: 0.3787 - val_loss: 2.4931
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.4039 - loss: 2.1928 - val_accuracy: 0.3693 - val_loss: 2.5106
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 89ms/step - accuracy: 0.4080 - loss: 2.1699 - val_accuracy: 0.3763 - val_loss: 2.4898
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.4089 - loss: 2.1675 - val_accuracy: 0.3734 - val_loss: 2.5219
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.4120 - loss: 2.1482 - val_accuracy: 0.3770 - val_loss: 2.5111
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 87ms/step - accuracy: 0.4164 - loss: 2.1322 - val_accuracy: 0.3849 - val_loss: 2.4857
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.4171 - loss: 2.1233 - val_accuracy: 0.3758 - val_loss: 2.5147
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 87ms/step - accuracy: 0.4164 - loss: 2.1190 - val_accuracy: 0.3742 - val_loss: 2.5051
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.4188 - loss: 2.1101 - val_accuracy: 0.3731 - val_loss: 2.5310
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.4188 - loss: 2.1010 - val_accuracy: 0.3739 - val_loss: 2.5470
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.4247 - loss: 2.0912 - val_accuracy: 0.3755 - val_loss: 2.5291
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.4214 - loss: 2.0809 - val_accuracy: 0.3793 - val_loss: 2.5353
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4220 - loss: 2.0735 - val_accuracy: 0.3726 - val_loss: 2.5499
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.4277 - loss: 2.0559 - val_accuracy: 0.3744 - val_loss: 2.5465
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.4258 - loss: 2.0600 - val_accuracy: 0.3703 - val_loss: 2.5995
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.4283 - loss: 2.0499 - val_accuracy: 0.3692 - val_loss: 2.5667
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.4323 - loss: 2.0382 - val_accuracy: 0.3753 - val_loss: 2.5477
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4318 - loss: 2.0381 - val_accuracy: 0.3746 - val_loss: 2.5669
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.4318 - loss: 2.0210 - val_accuracy: 0.3663 - val_loss: 2.6090
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4385 - loss: 2.0095 - val_accuracy: 0.3711 - val_loss: 2.6164
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4362 - loss: 2.0159 - val_accuracy: 0.3704 - val_loss: 2.5615
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.4423 - loss: 1.9942 - val_accuracy: 0.3776 - val_loss: 2.5712
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4407 - loss: 1.9918 - val_accuracy: 0.3695 - val_loss: 2.6236
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4424 - loss: 1.9844 - val_accuracy: 0.3706 - val_loss: 2.6004
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 87ms/step - accuracy: 0.4422 - loss: 1.9835 - val_accuracy: 0.3748 - val_loss: 2.6022
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.4439 - loss: 1.9644 - val_accuracy: 0.3748 - val_loss: 2.5989
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.4456 - loss: 1.9631 - val_accuracy: 0.3669 - val_loss: 2.6368
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 89ms/step - accuracy: 0.4483 - loss: 1.9547 - val_accuracy: 0.3719 - val_loss: 2.6330
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.4467 - loss: 1.9468 - val_accuracy: 0.3737 - val_loss: 2.6761
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.4482 - loss: 1.9440 - val_accuracy: 0.3711 - val_loss: 2.6872
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.4534 - loss: 1.9344 - val_accuracy: 0.3716 - val_loss: 2.6690
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 89ms/step - accuracy: 0.4518 - loss: 1.9317 - val_accuracy: 0.3711 - val_loss: 2.6836
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.4538 - loss: 1.9274 - val_accuracy: 0.3603 - val_loss: 2.7041
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.4531 - loss: 1.9226 - val_accuracy: 0.3703 - val_loss: 2.6798
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 77ms/step - accuracy: 0.4553 - loss: 1.9150 - val_accuracy: 0.3658 - val_loss: 2.6680
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 81ms/step - accuracy: 0.4552 - loss: 1.9105 - val_accuracy: 0.3704 - val_loss: 2.6875
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.4549 - loss: 1.9078 - val_accuracy: 0.3649 - val_loss: 2.7716
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 80ms/step - accuracy: 0.4568 - loss: 1.9039 - val_accuracy: 0.3693 - val_loss: 2.7386
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.4562 - loss: 1.8998 - val_accuracy: 0.3672 - val_loss: 2.7252
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 79ms/step - accuracy: 0.4592 - loss: 1.8933 - val_accuracy: 0.3726 - val_loss: 2.6762
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 80ms/step - accuracy: 0.4617 - loss: 1.8854 - val_accuracy: 0.3734 - val_loss: 2.6997
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.4613 - loss: 1.8754 - val_accuracy: 0.3682 - val_loss: 2.7376
#
# Test Accuracy (Scratch Model): 0.3682

# %% [markdown]
# #### Plot Training History

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_scratch.history['accuracy'], label='Training Accuracy')
plt.plot(history_scratch.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy (Scratch CNN)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_scratch.history['loss'], label='Training Loss')
plt.plot(history_scratch.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss (Scratch CNN)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
